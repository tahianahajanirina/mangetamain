# %%
from huggingface_hub import InferenceClient

# Ton token HF
client = InferenceClient(token="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")

# Utiliser ton modèle
result = client.text_classification(
    "This recipe was absolutely delicious! Will make again.",
    model="TahianaAndriambahoaka/sentiment-analysis-food-reviews"
)

print(result)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[3], line 7
#       4 client = InferenceClient(token="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")
#       6 # Utiliser ton modèle
# ----> 7 result = client.text_classification(
#       8     "This recipe was absolutely delicious! Will make again.",
#       9     model="TahianaAndriambahoaka/sentiment-analysis-food-reviews"
#      10 )
#      12 print(result)
#
# File e:\Cours Télécom Paris\IADATA700 - Kik Big Data - Charlotte LACLAU\Projet-groupe\mangetamain\venv\Lib\site-packages\huggingface_hub\inference\_client.py:1909, in InferenceClient.text_classification(self, text, model, top_k, function_to_apply)
#    1873 """
#    1874 Perform text classification (e.g. sentiment-analysis) on the given text.
#    1875
#    (...)   1906 ```
#    1907 """
#    1908 model_id = model or self.model
# ...

# %%
import requests

API_URL = "https://router.huggingface.co/hf-inference//models/TahianaAndriambahoaka/sentiment-analysis-food-reviews"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    
    # Debug: afficher le statut et le contenu brut
    print(f"Status code: {response.status_code}")
    print(f"Response text: {response.text}")
    
    # Vérifier si la réponse est OK
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": response.text}

# Test
result = query({"inputs": "This recipe was absolutely delicious! Will make again."})
print(result)
# Out:
# Status code: 404
# Response text: Not Found
# {'error': 'Not Found'}
